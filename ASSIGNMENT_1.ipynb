# %%
import pandas as pd
#from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split

# %%
dataf = pd.read_csv('Heart (1).csv')
dataf
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
dataf.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'Sex', 'ChestPain', 'RestBP', 'Chol', 'Fbs',
#        'RestECG', 'MaxHR', 'ExAng', 'Oldpeak', 'Slope', 'Ca', 'Thal', 'AHD'],
#       dtype='object')

# %%
dataf= dataf.drop("Unnamed: 0" , axis = 1)
dataf
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 2     67    1  asymptomatic     120   229    0        2    129      1
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 0        2.3      3  0.0       fixed   No
# ...

# %%
# To print the shape of the data
dataf.shape
# Out:
# (303, 14)

# %%
dataf.nunique()
# Out:
# Age           41
# Sex            2
# ChestPain      4
# RestBP        50
# Chol         152
# Fbs            2
# RestECG        3
# MaxHR         91
# ExAng          2
# Oldpeak       40
# Slope          3
# Ca             4
# Thal           3
# AHD            2
# dtype: int64

# %%
# Checking that is that data null or not in each column
dataf.isnull().sum()
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           4
# Thal         2
# AHD          0
# dtype: int64

# %%
dataf.isnull()
# Out:
#        Age    Sex  ChestPain  RestBP   Chol    Fbs  RestECG  MaxHR  ExAng  \
# 0    False  False      False   False  False  False    False  False  False
# 1    False  False      False   False  False  False    False  False  False
# 2    False  False      False   False  False  False    False  False  False
# 3    False  False      False   False  False  False    False  False  False
# 4    False  False      False   False  False  False    False  False  False
# ..     ...    ...        ...     ...    ...    ...      ...    ...    ...
# 298  False  False      False   False  False  False    False  False  False
# 299  False  False      False   False  False  False    False  False  False
# 300  False  False      False   False  False  False    False  False  False
# 301  False  False      False   False  False  False    False  False  False
# 302  False  False      False   False  False  False    False  False  False
#
#      Oldpeak  Slope     Ca   Thal    AHD
# ...

# %%
# How many values are not null in each column
dataf.notnull().sum()
# Out:
# Age          303
# Sex          303
# ChestPain    303
# RestBP       303
# Chol         303
# Fbs          303
# RestECG      303
# MaxHR        303
# ExAng        303
# Oldpeak      303
# Slope        303
# Ca           299
# Thal         301
# AHD          303
# dtype: int64

# %%
dataf.notnull()
# Out:
#       Age   Sex  ChestPain  RestBP  Chol   Fbs  RestECG  MaxHR  ExAng  \
# 0    True  True       True    True  True  True     True   True   True
# 1    True  True       True    True  True  True     True   True   True
# 2    True  True       True    True  True  True     True   True   True
# 3    True  True       True    True  True  True     True   True   True
# 4    True  True       True    True  True  True     True   True   True
# ..    ...   ...        ...     ...   ...   ...      ...    ...    ...
# 298  True  True       True    True  True  True     True   True   True
# 299  True  True       True    True  True  True     True   True   True
# 300  True  True       True    True  True  True     True   True   True
# 301  True  True       True    True  True  True     True   True   True
# 302  True  True       True    True  True  True     True   True   True
#
#      Oldpeak  Slope     Ca  Thal   AHD
# 0       True   True   True  True  True
# 1       True   True   True  True  True
# ...

# %%
# Getting data types of each columns
dataf.dtypes
# Out:
# Age            int64
# Sex            int64
# ChestPain     object
# RestBP         int64
# Chol           int64
# Fbs            int64
# RestECG        int64
# MaxHR          int64
# ExAng          int64
# Oldpeak      float64
# Slope          int64
# Ca           float64
# Thal          object
# AHD           object
# dtype: object

# %%
for col in dataf.columns:
    column = dataf[col]
    count = (column == 0).sum()
    print("The number of the zeros in ", col, " are ",count)
# Out:
# The number of the zeros in  Age  are  0
# The number of the zeros in  Sex  are  97
# The number of the zeros in  ChestPain  are  0
# The number of the zeros in  RestBP  are  0
# The number of the zeros in  Chol  are  0
# The number of the zeros in  Fbs  are  258
# The number of the zeros in  RestECG  are  151
# The number of the zeros in  MaxHR  are  0
# The number of the zeros in  ExAng  are  204
# The number of the zeros in  Oldpeak  are  99
# The number of the zeros in  Slope  are  0
# The number of the zeros in  Ca  are  176
# The number of the zeros in  Thal  are  0
# The number of the zeros in  AHD  are  0

# %%
# To find the mean age

dataf['Age'].mean()
# Out:
# 54.43894389438944

# %%
dataf.loc[:,["Age","Sex","ChestPain","RestBP","Chol"]]
# Out:
#      Age  Sex     ChestPain  RestBP  Chol
# 0     63    1       typical     145   233
# 1     67    1  asymptomatic     160   286
# 2     67    1  asymptomatic     120   229
# 3     37    1    nonanginal     130   250
# 4     41    0    nontypical     130   204
# ..   ...  ...           ...     ...   ...
# 298   45    1       typical     110   264
# 299   68    1  asymptomatic     144   193
# 300   57    1  asymptomatic     130   131
# 301   57    0    nontypical     130   236
# 302   38    1    nonanginal     138   175
#
# [303 rows x 5 columns]

# %%
dataf[["Age","Sex","ChestPain","RestBP","Chol"]]
# Out:
#      Age  Sex     ChestPain  RestBP  Chol
# 0     63    1       typical     145   233
# 1     67    1  asymptomatic     160   286
# 2     67    1  asymptomatic     120   229
# 3     37    1    nonanginal     130   250
# 4     41    0    nontypical     130   204
# ..   ...  ...           ...     ...   ...
# 298   45    1       typical     110   264
# 299   68    1  asymptomatic     144   193
# 300   57    1  asymptomatic     130   131
# 301   57    0    nontypical     130   236
# 302   38    1    nonanginal     138   175
#
# [303 rows x 5 columns]

# %%
X = dataf[['Age','Chol']]
y = dataf['AHD']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.7,test_size=0.3,shuffle=False)

# %%
X_train.shape
# Out:
# (212, 2)

# %%
y_train.shape
# Out:
# (212,)

# %%
X_test.shape
# Out:
# (91, 2)

# %%
y_test.shape
# Out:
# (91,)

# %%
y_train.shape
# Out:
# (212,)

# %%
X_train
# Out:
#      Age  Chol
# 0     63   233
# 1     67   286
# 2     67   229
# 3     37   250
# 4     41   204
# ..   ...   ...
# 207   50   200
# 208   55   262
# 209   62   244
# 210   37   215
# 211   38   231
#
# [212 rows x 2 columns]
